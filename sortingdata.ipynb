# %%
import pandas as pd

# %%
movies_info = pd.read_csv('database.csv')

# %%
movies_info.head()
# Out:
#          Date      Time  Latitude  Longitude        Type  Depth  Depth Error  \
# 0  01/02/1965  13:44:18    19.246    145.616  Earthquake  131.6          NaN
# 1  01/04/1965  11:29:49     1.863    127.352  Earthquake   80.0          NaN
# 2  01/05/1965  18:05:58   -20.579   -173.972  Earthquake   20.0          NaN
# 3  01/08/1965  18:49:43   -59.076    -23.557  Earthquake   15.0          NaN
# 4  01/09/1965  13:32:50    11.938    126.427  Earthquake   15.0          NaN
#
#    Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 0                     NaN        6.0             MW  ...
# 1                     NaN        5.8             MW  ...
# 2                     NaN        6.2             MW  ...
# 3                     NaN        5.8             MW  ...
# 4                     NaN        5.8             MW  ...
#
#    Magnitude Seismic Stations  Azimuthal Gap  Horizontal Distance  \
# 0                         NaN            NaN                  NaN
# ...

# %%
len(movies_info)
# Out:
# 23412

# %%
grouped = movies_info.groupby('Latitude')

# %%
grouped.groups
# Out:
# {-77.08: [21304], -72.448: [11457], -67.034: [18716], -66.448: [4237], -65.721: [5717], -65.651: [16851], -65.635: [6021], -65.5984: [22533], -65.592: [14108], -65.552: [21688], -65.543: [2692], -65.526: [13677], -65.478: [21403], -65.458: [9306], -65.436: [8857], -65.425: [20096], -65.417: [17724], -65.346: [10949], -65.198: [16691], -65.114: [8691], -64.969: [21445], -64.944: [4346], -64.872: [5317], -64.519: [11981], -63.884: [13490], -63.723: [9536], -63.68: [14524], -63.66: [660], -63.653: [10215], -63.622: [14842], -63.612: [13926], -63.607: [14073], -63.592: [20384], -63.581: [21400], -63.563: [16871], -63.561: [13927], -63.497: [14285], -63.47: [13957], -63.4595: [22422], -63.398: [1846], -63.38: [16870], -63.378: [21826], -63.364: [6691], -63.342: [9723], -63.337: [18403], -63.31: [4868], -63.2943: [21974], -63.289: [14497], -63.263: [22979], -63.245: [21052], -63.211: [9724], -63.204: [16869], -63.197: [4869], -63.159: [192], -63.123: [14588], -63.122: [13665], -63.091: [63
# ...

# %%
len(grouped.groups)
# Out:
# 20676

# %%
movies_info['Latitude'].nunique()
# Out:
# 20676

# %%
grouped.size()
# Out:
# Latitude
# -77.080    1
# -72.448    1
# -67.034    1
# -66.448    1
# -65.721    1
#           ..
#  85.686    1
#  85.734    1
#  85.735    1
#  85.992    1
#  86.005    1
# Length: 20676, dtype: int64

# %%
grouped_1 = movies_info.groupby(['Latitude','Longitude'])

# %%
grouped_1.groups
# Out:
# {(-77.08, -148.864): [21304], (-72.448, 174.838): [11457], (-67.034, 111.199): [18716], (-66.448, -82.584): [4237], (-65.721, -175.714): [5717], (-65.651, -179.574): [16851], (-65.635, 179.899): [6021], (-65.5984, -179.601): [22533], (-65.592, -177.115): [14108], (-65.552, -177.804): [21688], (-65.543, 179.33): [2692], (-65.526, 178.813): [13677], (-65.478, -179.778): [21403], (-65.458, -179.993): [9306], (-65.436, 179.638): [8857], (-65.425, 179.875): [20096], (-65.417, 179.489): [17724], (-65.346, 178.521): [10949], (-65.198, 179.71): [16691], (-65.114, 177.537): [8691], (-64.969, 177.83): [21445], (-64.944, 175.687): [4346], (-64.872, -170.537): [5317], (-64.519, 175.22): [11981], (-63.884, -158.801): [13490], (-63.723, -156.105): [9536], (-63.68, -167.163): [14524], (-63.66, -167.459): [660], (-63.653, 172.65): [10215], (-63.622, 172.741): [14842], (-63.612, 147.937): [13926], (-63.607, 147.488): [14073], (-63.592, -167.354): [20384], (-63.581, 171.324): [21400], (-63.563, -166.6
# ...

# %%
grouped_1.size()
# Out:
# Latitude  Longitude
# -77.080   -148.864     1
# -72.448    174.838     1
# -67.034    111.199     1
# -66.448   -82.584      1
# -65.721   -175.714     1
#                       ..
#  85.686    86.034      1
#  85.734    84.439      1
#  85.735    84.906      1
#  85.992    30.825      1
#  86.005    31.595      1
# Length: 23406, dtype: int64

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 grouped.get_group('Magnitude')
#
# File ~\anaconda3\New folder\Lib\site-packages\pandas\core\groupby\groupby.py:1114, in BaseGroupBy.get_group(self, name, obj)
#    1112 inds = self._get_index(name)
#    1113 if not len(inds):
# -> 1114     raise KeyError(name)
#    1116 if obj is None:
#    1117     indexer = inds if self.axis == 0 else (slice(None), inds)
#
# KeyError: 'Magnitude'

# %%
for Latitude,group in grouped:
    print("Latitude name:",Latitude)
    print(group[['Latitude','Longitude']],'\n')
# Out:
# Latitude name: -77.08
#        Latitude  Longitude
# 21304    -77.08   -148.864
#
# Latitude name: -72.448
#        Latitude  Longitude
# 11457   -72.448    174.838
#
# Latitude name: -67.034
#        Latitude  Longitude
# 18716   -67.034    111.199
#
# Latitude name: -66.448
#       Latitude  Longitude
# 4237   -66.448    -82.584
#
# Latitude name: -65.721
#       Latitude  Longitude
# 5717   -65.721   -175.714
#
# Latitude name: -65.651
#        Latitude  Longitude
# 16851   -65.651   -179.574
#
# Latitude name: -65.635
#       Latitude  Longitude
# 6021   -65.635    179.899
#
# Latitude name: -65.5984
#        Latitude  Longitude
# 22533  -65.5984   -179.601
#
# Latitude name: -65.592
#        Latitude  Longitude
# 14108   -65.592   -177.115
#
# Latitude name: -65.552
#        Latitude  Longitude
# 21688   -65.552   -177.804
#
# Latitude name: -65.543
#       Latitude  Longitude
# 2692   -65.543     179.33
#
# Latitude name: -65.526
#        Latitude  Longitude
# ...

# %%
grouped.first()
# Out:
#                 Date      Time  Longitude        Type  Depth  Depth Error  \
# Latitude
# -77.080   06/01/2012  05:07:02   -148.864  Earthquake   12.0          NaN
# -72.448   05/31/1993  08:34:22    174.838  Earthquake   10.0          NaN
# -67.034   11/04/2007  20:35:37    111.199  Earthquake   10.0          NaN
# -66.448   02/05/1977  03:29:19    -82.584  Earthquake   33.0          NaN
# -65.721   12/09/1980  09:05:44   -175.714  Earthquake   10.0          NaN
# ...              ...       ...        ...         ...    ...          ...
#  85.686   03/01/1999  17:46:46     86.034  Earthquake   10.0          NaN
#  85.734   02/01/1999  09:56:35     84.439  Earthquake   10.0          NaN
#  85.735   03/04/1999  07:52:46     84.906  Earthquake   10.0          NaN
#  85.992   11/09/1973  13:42:43     30.825  Earthquake   15.0          NaN
#  86.005   05/03/2002  11:20:52     31.595  Earthquake   10.0          NaN
#
# ...

# %%
grouped_1.first()
# Out:
#                           Date      Time        Type  Depth  Depth Error  \
# Latitude Longitude
# -77.080  -148.864   06/01/2012  05:07:02  Earthquake   12.0          NaN
# -72.448   174.838   05/31/1993  08:34:22  Earthquake   10.0          NaN
# -67.034   111.199   11/04/2007  20:35:37  Earthquake   10.0          NaN
# -66.448  -82.584    02/05/1977  03:29:19  Earthquake   33.0          NaN
# -65.721  -175.714   12/09/1980  09:05:44  Earthquake   10.0          NaN
# ...                        ...       ...         ...    ...          ...
#  85.686   86.034    03/01/1999  17:46:46  Earthquake   10.0          NaN
#  85.734   84.439    02/01/1999  09:56:35  Earthquake   10.0          NaN
#  85.735   84.906    03/04/1999  07:52:46  Earthquake   10.0          NaN
#  85.992   30.825    11/09/1973  13:42:43  Earthquake   15.0          NaN
#  86.005   31.595    05/03/2002  11:20:52  Earthquake   10.0          NaN
#
#                     Depth Seismic Stations  Magnitude Magnitude Type  \
# ...

# %%
grouped.nth(2)
# Out:
#              Date      Time  Latitude  Longitude        Type  Depth  \
# 1849   02/09/1971  14:02:46    34.416  -118.3700  Earthquake    6.0
# 3496   06/13/1975  18:08:12    43.489   147.7090  Earthquake   19.0
# 3637   10/03/1975  11:51:09   -22.126   126.7210  Earthquake   33.0
# 4958   09/28/1978  09:38:33    51.258   159.7930  Earthquake   33.0
# 5454   02/27/1980  12:44:27    43.269   146.8450  Earthquake   42.0
# ...           ...       ...       ...        ...         ...    ...
# 21882  09/04/2013  04:16:30    51.449  -174.7170  Earthquake   26.6
# 21884  09/04/2013  06:27:04    51.573  -174.8537  Earthquake   17.0
# 21951  11/07/2013  16:46:35   -22.324   171.5445  Earthquake   98.0
# 22010  12/28/2013  15:21:04    36.028    31.3100  Earthquake   40.7
# 22347  08/20/2014  10:14:16    32.636    47.7360  Earthquake   17.7
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# 1849           NaN                     0.0        5.8             MH  ...
# ...

# %%
grouped_1.first()
# Out:
#                           Date      Time        Type  Depth  Depth Error  \
# Latitude Longitude
# -77.080  -148.864   06/01/2012  05:07:02  Earthquake   12.0          NaN
# -72.448   174.838   05/31/1993  08:34:22  Earthquake   10.0          NaN
# -67.034   111.199   11/04/2007  20:35:37  Earthquake   10.0          NaN
# -66.448  -82.584    02/05/1977  03:29:19  Earthquake   33.0          NaN
# -65.721  -175.714   12/09/1980  09:05:44  Earthquake   10.0          NaN
# ...                        ...       ...         ...    ...          ...
#  85.686   86.034    03/01/1999  17:46:46  Earthquake   10.0          NaN
#  85.734   84.439    02/01/1999  09:56:35  Earthquake   10.0          NaN
#  85.735   84.906    03/04/1999  07:52:46  Earthquake   10.0          NaN
#  85.992   30.825    11/09/1973  13:42:43  Earthquake   15.0          NaN
#  86.005   31.595    05/03/2002  11:20:52  Earthquake   10.0          NaN
#
#                     Depth Seismic Stations  Magnitude Magnitude Type  \
# ...

# %%
grouped_2 = movies_info.groupby('Longitude',sort=False)

# %%
grouped_2.groups
# Out:
# {145.616: [0], 127.352: [1], -173.972: [2, 17879], -23.557: [3], 126.427: [4], 166.629: [5], 87.867: [6], 166.212: [7], -27.043: [8, 18854], 178.487: [9], 108.988: [10], 125.952: [11], 161.703: [12], -177.864: [13], 73.251: [14], 139.741: [15], 178.715: [16, 10687], 175.055: [17], 172.007: [18], 175.746: [19], 177.848: [20], 173.975: [21], 173.058: [22], 172.588: [23], 174.368: [24], 173.969: [25], 179.605: [26], 171.974: [27], 174.696: [28], 171.091: [29], 170.874: [30], 175.045: [31], -44.922: [32], 174.206: [33], 174.841: [34], 174.321: [35], 173.84: [36], 174.566: [37], 176.558: [38], -162.008: [39], 175.505: [40], 172.918: [41], 175.213: [42], 174.116: [43], -161.859: [44], 176.469: [45], 173.393: [46], 175.411: [47], 179.092: [48], 165.426: [49], 169.386: [50], 171.904: [51], 172.752: [52], 179.325: [53], 125.951: [54], 142.095: [55], 176.446: [56], 143.081: [57], 94.186: [58], 126.715: [59, 1859, 2701], 179.358: [60], -172.889: [61, 11367], -70.679: [62], 151.98: [63], 173.072
# ...

# %%
movies_info.groupby('Longitude')[['Depth']].mean()
# Out:
#             Depth
# Longitude
# -179.997   392.30
# -179.996   542.60
# -179.993    10.00
# -179.991   550.00
# -179.989   535.20
# ...           ...
#  179.981   540.00
#  179.984   548.80
#  179.989    33.00
#  179.992   520.90
#  179.998   393.05
#
# [21474 rows x 1 columns]

# %%
movies_info.groupby(['Latitude','Depth']).size()
# Out:
# Latitude  Depth
# -77.080   12.0     1
# -72.448   10.0     1
# -67.034   10.0     1
# -66.448   33.0     1
# -65.721   10.0     1
#                   ..
#  85.686   10.0     1
#  85.734   10.0     1
#  85.735   10.0     1
#  85.992   15.0     1
#  86.005   10.0     1
# Length: 23199, dtype: int64

# %%
movies_info.groupby('Longitude')[['Magnitude']].min()
# Out:
#            Magnitude
# Longitude
# -179.997         6.2
# -179.996         5.6
# -179.993         5.8
# -179.991         5.8
# -179.989         6.4
# ...              ...
#  179.981         6.0
#  179.984         5.5
#  179.989         5.6
#  179.992         5.6
#  179.998         6.2
#
# [21474 rows x 1 columns]

# %%
movies_info.groupby('Latitude').size()
# Out:
# Latitude
# -77.080    1
# -72.448    1
# -67.034    1
# -66.448    1
# -65.721    1
#           ..
#  85.686    1
#  85.734    1
#  85.735    1
#  85.992    1
#  86.005    1
# Length: 20676, dtype: int64

# %%
movies_info.groupby('Latitude')[['Depth']].apply(lambda gr: gr.max())
# Out:
#           Depth
# Latitude
# -77.080    12.0
# -72.448    10.0
# -67.034    10.0
# -66.448    33.0
# -65.721    10.0
# ...         ...
#  85.686    10.0
#  85.734    10.0
#  85.735    10.0
#  85.992    15.0
#  86.005    10.0
#
# [20676 rows x 1 columns]

# %%
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_11260\4196866628.py:1: FutureWarning: The provided callable <built-in function max> is currently using np.maximum.reduce. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string np.maximum.reduce instead.
#   movies_info.groupby('Latitude')[['Longitude']].apply(max)
#           Longitude
# Latitude
# -77.080    -148.864
# -72.448     174.838
# -67.034     111.199
# -66.448     -82.584
# -65.721    -175.714
# ...             ...
#  85.686      86.034
#  85.734      84.439
#  85.735      84.906
#  85.992      30.825
#  86.005      31.595
#
# [20676 rows x 1 columns]

# %%
movies_info.groupby('Longitude')['Depth'].agg(['count','min','max','mean'])
# Out:
#            count    min    max    mean
# Longitude
# -179.997       1  392.3  392.3  392.30
# -179.996       1  542.6  542.6  542.60
# -179.993       1   10.0   10.0   10.00
# -179.991       1  550.0  550.0  550.00
# -179.989       1  535.2  535.2  535.20
# ...          ...    ...    ...     ...
#  179.981       1  540.0  540.0  540.00
#  179.984       1  548.8  548.8  548.80
#  179.989       1   33.0   33.0   33.00
#  179.992       1  520.9  520.9  520.90
#  179.998       2  369.4  416.7  393.05
#
# [21474 rows x 4 columns]

# %%
movies_info.groupby('Longitude').agg({'Depth':['max','min'],'Latitude':['mean','max']})
# Out:
#            Depth        Latitude
#              max    min     mean     max
# Longitude
# -179.997   392.3  392.3 -31.5660 -31.566
# -179.996   542.6  542.6 -23.4950 -23.495
# -179.993    10.0   10.0 -65.4580 -65.458
# -179.991   550.0  550.0 -23.6330 -23.633
# -179.989   535.2  535.2 -23.6070 -23.607
# ...          ...    ...      ...     ...
#  179.981   540.0  540.0 -23.7210 -23.721
#  179.984   548.8  548.8 -24.1680 -24.168
#  179.989    33.0   33.0 -37.4230 -37.423
#  179.992   520.9  520.9 -23.7860 -23.786
#  179.998   416.7  369.4 -31.0625 -30.965
#
# [21474 rows x 4 columns]

# %%
movies_info.groupby('Longitude').agg({'Depth':'mean','Latitude':'max'})
# Out:
#             Depth  Latitude
# Longitude
# -179.997   392.30   -31.566
# -179.996   542.60   -23.495
# -179.993    10.00   -65.458
# -179.991   550.00   -23.633
# -179.989   535.20   -23.607
# ...           ...       ...
#  179.981   540.00   -23.721
#  179.984   548.80   -24.168
#  179.989    33.00   -37.423
#  179.992   520.90   -23.786
#  179.998   393.05   -30.965
#
# [21474 rows x 2 columns]

# %%
movies_info.groupby('Latitude').filter(lambda x: x['Depth'].mean()>=4)
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
movies_combine = movies_info.groupby('Latitude').agg({'Depth':['max','min'],'Depth':['mean','max']})

# %%
type(movies_combine)
# Out:
# pandas.core.frame.DataFrame

# %%
movies_combine.head()
# Out:
#          Depth
#           mean   max
# Latitude
# -77.080   12.0  12.0
# -72.448   10.0  10.0
# -67.034   10.0  10.0
# -66.448   33.0  33.0
# -65.721   10.0  10.0

# %%
pd.DataFrame(movies_info.groupby('Longitude').size(),columns=['number'])
# Out:
#            number
# Longitude
# -179.997        1
# -179.996        1
# -179.993        1
# -179.991        1
# -179.989        1
# ...           ...
#  179.981        1
#  179.984        1
#  179.989        1
#  179.992        1
#  179.998        2
#
# [21474 rows x 1 columns]
